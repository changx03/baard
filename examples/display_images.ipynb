# %%
import os
from pathlib import Path

from baard.utils.miscellaneous import plot_images

# %%
PATH_ROOT = Path(os.getcwd()).absolute().parent
print(PATH_ROOT)
# Out:
# /home/lukec/workspace/baard_v4

# %%
path_img = os.path.join(PATH_ROOT, 'results', 'exp1234', 'MNIST')
plot_images(path_img, 'L2', [0.5, 1, 2, 4, 6, 8], 'APGD', n=100)
# Out:
# Labels: 9, 7, 5, 5, 5
# Clean images
# Labels: 9, 7, 5, 5, 5
# APGD L2 eps=0.5
# Labels: 9, 7, 5, 5, 5
# APGD L2 eps=1
# Labels: 9, 7, 5, 5, 5
# APGD L2 eps=2
# Labels: 9, 7, 5, 5, 5
# APGD L2 eps=4
# Labels: 9, 7, 5, 5, 5
# APGD L2 eps=6
# Labels: 9, 7, 5, 5, 5
# APGD L2 eps=8
