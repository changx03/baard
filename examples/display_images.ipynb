# %%
import os
from pathlib import Path

import torch
import numpy as np
import matplotlib.pyplot as plt
import torchvision as tv
import torchvision.transforms.functional as tvF

# %%
PATH_ROOT = Path(os.getcwd()).absolute().parent
print(PATH_ROOT)
# Out:
# /home/lukec/workspace/baard_v4

# %%
def show_top5_imgs(path_dataset,figsize=(8, 3), cmap='gray'):
    dataset = torch.load(path_dataset)
    images = [x for x, y in dataset]
    labels = [y for x, y in dataset]
    grid = tv.utils.make_grid(images[:5], nrow=5, padding=4, pad_value=1)
    grid = grid.permute(1,2,0)
    
    plt.figure(figsize=figsize)
    plt.imshow(grid.numpy(), cmap=cmap)
    plt.axis('off')
    plt.show()
    
    lbl_str = ', '.join([str(l.item()) for l in labels[:5]])
    print(f'Labels: {lbl_str}')

# %%
path_img = os.path.join(PATH_ROOT, 'results', 'exp1234', 'MNIST', 'FGSM.L2.n_100.e_64.pt')
show_top5_imgs(path_img)
# Out:
# Labels: 9, 7, 5, 5, 5

# %%
path_img = os.path.join(PATH_ROOT, 'results', 'exp1234', 'MNIST', 'PGD.n_100.e_0.12.pt')
show_top5_imgs(path_img)
# Out:
# Labels: 9, 7, 5, 5, 5

# %%
path_img = os.path.join(PATH_ROOT, 'results', 'exp1234', 'CIFAR10', 'FGSM.n_100.e_0.31.pt')
show_top5_imgs(path_img, cmap=None)
# Out:
# Labels: 2, 1, 7, 4, 7

# %%
path_img = os.path.join(PATH_ROOT, 'results', 'exp1234', 'CIFAR10', 'FGSM.n_100.e_0.03.pt')
show_top5_imgs(path_img, cmap=None)
# Out:
# Labels: 2, 1, 7, 4, 7

# %%
path_img = os.path.join(PATH_ROOT, 'results', 'exp1234', 'CIFAR10', 'PGD.n_100.e_0.12.pt')
show_top5_imgs(path_img, cmap=None)
# Out:
# Labels: 2, 1, 7, 4, 7
